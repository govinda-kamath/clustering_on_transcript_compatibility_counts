# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# Load data
with open('/data/SS_RNA_seq/Code/sparse_eq_class.dat', 'rb') as infile:
    X = pickle.load(infile)

print np.shape(X)
# Out:
# (1512, 297305)

# %%
# Functions that are helpful for analysis

from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn import cluster
import sklearn.metrics
from sklearn.metrics.pairwise import pairwise_distances
from scipy.stats import entropy

# Normalize rows of X (such that each is a distribution)
def data_to_dist(X):
    s = np.sum(X,axis=1)
    X = X / s[:,None]
    return X

# obtain labels via kmeans
def jz_kmeans(X,k):
    k_means = cluster.KMeans(n_clusters=k,max_iter=50,precompute_distances=True)
    k_means.fit(X)
    labels = k_means.labels_
    return labels

# obtain labels via spectral clustering
def jz_spectral(X,k,dist_funct,nj=64):
    # Compute pairwise distances
    D = pairwise_distances(X,metric=dist_funct,n_jobs=nj)
    if D[1,1] < 1: D = np.exp(-D**2) # Convert distance to similarity matrix
    spectral = cluster.SpectralClustering(n_clusters=k,affinity='precomputed')
    spectral.fit(D)
    labels = spectral.labels_
    return labels,D

# obtain two major directions from t-SNE
def jz_tSNE(X):
    tsne = manifold.TSNE(n_components=2, random_state=0);
    X_tsne = tsne.fit_transform(X);
    return X_tsne

# Distance metrics (input: X with m samples, output: m-by-m distance matrix)
def shannon_jensen(p, q):
#    pshape=np.shape(p)
#    qshape=np.shape(q)
#    assert pshape[1]==1
#    assert qshape[1]==1
#    assert pshape[0]==qshape[0]
#    assert min(p) >= 0
#    assert min(q) >= 0
#    assert sum(p)<=1 + np.finfo(float).eps and sum(p) >= 1- np.finfo(float).eps
#    assert sum(q)<=1 + np.finfo(float).eps and sum(q) >= 1- np.finfo(float).eps
    m=0.5*p+0.5*q
    ind = np.where(m != 0)
    return 0.5*entropy(p[ind],m[ind]) + 0.5*entropy(q[ind],m[ind])

# %%
# t-SNE on original data

# %matplotlib inline

X_tsne = jz_tSNE(X)
plt.figure(figsize=(15,15))

# plot and color points using batch numbers
plt.scatter(X_tsne[:,0], X_tsne[:, 1])

# %%
# generate kmeans labels
import colorsys
k = 47
HSV_tuples = [(x*1.0/k, 0.5, 0.5) for x in range(k)]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)

# %matplotlib inline

# plot and color using kmeans labels
labels = jz_kmeans(X,k)
unique_labels = np.unique(labels)
plt.figure(figsize=(15,15))
for label in unique_labels:
    plt.scatter(X_tsne[labels == label,0],X_tsne[labels == label,1],c=np.random.rand(3))

# %%
# generate kmeans labels
import colorsys
k = 9
HSV_tuples = [(x*1.0/k, 0.5, 0.5) for x in range(k)]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)

# %matplotlib inline

# plot and color using kmeans labels
#labels9 = jz_kmeans(X,k)
unique_labels = np.unique(labels9)
plt.figure(figsize=(15,15))
for label in unique_labels:
    plt.scatter(X_tsne[labels9 == label,0],X_tsne[labels9 == label,1],c=np.random.rand(3))

# %%
# generate spectral clustering labels (using jensen-shannon distance)

# plot and color using spectral clustering labels
labels,D_js = jz_spectral(X,47,shannon_jensen)
unique_labels = np.unique(labels)
plt.figure(figsize=(15,15))
for label in unique_labels:
    plt.scatter(X_tsne[labels == label,0],X_tsne[labels == label,1],c=np.random.rand(3))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-69384e05af60> in <module>()
#       2
#       3 # plot and color using spectral clustering labels
# ----> 4 labels,D_js = jz_spectral(X,47,shannon_jensen)
#       5 unique_labels = np.unique(labels)
#       6 plt.figure(figsize=(15,15))
#
# <ipython-input-63-68cb734c6385> in jz_spectral(X, k, dist_funct, nj)
#      24 def jz_spectral(X,k,dist_funct,nj=64):
#      25     # Compute pairwise distances
# ---> 26     D = pairwise_distances(X,metric=dist_funct,n_jobs=nj)
#      27     if D[1,1] < 1: D = np.exp(-D**2) # Convert distance to similarity matrix
#      28     spectral = cluster.SpectralClustering(n_clusters=k,affinity='precomputed')
#
# /home/govinda/anaconda/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1108         func = partial(distance.cdist, metric=metric, **kwds)
#    1109
# -> 1110     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1111
#    1112
#
# /home/govinda/anaconda/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#     964     ret = Parallel(n_jobs=n_jobs, verbose=0)(
#     965         fd(X, Y[s], **kwds)
# --> 966         for s in gen_even_slices(Y.shape[0], n_jobs))
#     967
#     968     return np.hstack(ret)
#
# /home/govinda/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     664                 # consumption.
#     665                 self._iterating = False
# --> 666             self.retrieve()
#     667             # Make sure that we get a last message telling us we are done
#     668             elapsed_time = time.time() - self._start_time
#
# /home/govinda/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     530                             # We can now allow subprocesses again
#     531                             os.environ.pop('__JOBLIB_SPAWNED_PARALLEL__', 0)
# --> 532                         raise exception
#     533                     elif isinstance(exception, TransportableException):
#     534                         # Capture exception to add information on the local
#
# KeyboardInterrupt:

# %%
D = pairwise_distances(X,metric=shannon_jensen,n_jobs=64)
